# %%
## Refer Official documentation on chat from LangChain

from langchain.chat_models import ChatOpenAI
from langchain_openai import ChatOpenAI
from langchain.llms import OpenAI
from langchain.chains import LLMChain
from langchain import PromptTemplate
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    AIMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)


# Supporting libraries
import os

# %%
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
from constant import openai_key

os.environ['OPENAI_API_KEY']=openai_key

# %% [markdown]
# #### 0. Simple Input/Output Still works
#
#
# You just need to pass it as a message instead. More on this in a second.

# %%
chat = ChatOpenAI(openai_api_key=OPENAI_API_KEY)

# %%
message = [HumanMessage(content="What is the capital of USA?")]

chat(message)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[31], line 3
#       1 message = [HumanMessage(content="What is the capital of USA?")]
# ----> 3 chat(message)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:691, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     683 @deprecated("0.1.7", alternative="invoke", removal="0.2.0")
#     684 def __call__(
#     685     self,
#    (...)
#     689     **kwargs: Any,
#     690 ) -> BaseMessage:
# --> 691     generation = self.generate(
# ...

# %% [markdown]
# 1. Chat Messages
# - HumanMessage: A message sent from the perspective of the human
# - AIMessage: A message sent from the perspective of the AI the human is interacting with
# - SystemMessage: A message setting the objectives the AI should follow
# - ChatMessage: A message allowing for arbitrary setting of role. You won’t be using this too much

# %%
messages = [
    SystemMessage(content="Say the opposite of what the user says"),
    HumanMessage(content="I love programming.")
]
chat(messages)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 5
#       1 messages = [
#       2     SystemMessage(content="Say the opposite of what the user says"),
#       3     HumanMessage(content="I love programming.")
#       4 ]
# ----> 5 chat(messages)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:691, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     683 @deprecated("0.1.7", alternative="invoke", removal="0.2.0")
#     684 def __call__(
#     685     self,
#    (...)
# ...

# %%
messages = [
    SystemMessage(content="Say the opposite of what the user says"),
    HumanMessage(content="I love programming."),
    AIMessage(content='I hate programming.'),
    HumanMessage(content="The sky is pink")
]
chat(messages)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 7
#       1 messages = [
#       2     SystemMessage(content="Say the opposite of what the user says"),
#       3     HumanMessage(content="I love programming."),
#       4     AIMessage(content='I hate programming.'),
#       5     HumanMessage(content="The sky is pink")
#       6 ]
# ----> 7 chat(messages)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:691, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
# ...

# %%
messages = [
    SystemMessage(content="Say the opposite of what the user says"),
    HumanMessage(content="I love programming."),
    AIMessage(content='I hate programming.'),
    HumanMessage(content="What is the first thing that I said?")
]
chat(messages)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[8], line 7
#       1 messages = [
#       2     SystemMessage(content="Say the opposite of what the user says"),
#       3     HumanMessage(content="I love programming."),
#       4     AIMessage(content='I hate programming.'),
#       5     HumanMessage(content="What is the first thing that I said?")
#       6 ]
# ----> 7 chat(messages)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:691, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
# ...

# %% [markdown]
# #### Batch Messages

# %%
batch_messages = [
    [
        SystemMessage(content="You are a helpful word machine that creates an alliteration using a base word"),
        HumanMessage(content="Base word: Apple")
    ],
    [
        SystemMessage(content="You are a helpful word machine that creates an alliteration using a base word"),
        HumanMessage(content="Base word: Dog")
    ],
]
chat.generate(batch_messages)

# %% [markdown]
# ##### Prompt Templates
#
# With one or more `MessagePromptTemplates` you can build a `ChatPromptTemplate`

# %%
# Make SystemMessagePromptTemplate
prompt=PromptTemplate(
    template="Propose creative ways to incorporate {food_1} and {food_2} in the cuisine of the users choice.",
    input_variables=["food_1", "food_2"]
)

system_message_prompt = SystemMessagePromptTemplate(prompt=prompt)

# %%
# Output of system_message_prompt
system_message_prompt.format(food_1="Bacon", food_2="Shrimp")
# Out:
# SystemMessage(content='Propose creative ways to incorporate Bacon and Shrimp in the cuisine of the users choice.')

# %%
# Output of system_message_prompt
system_message_prompt.format(food_1="Sushi", food_2="Tacos")
# Out:
# SystemMessage(content='Propose creative ways to incorporate Sushi and Tacos in the cuisine of the users choice.')

# %%
# Make HumanMessagePromptTemplate
human_template="{text}"
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

# %%
# Create ChatPromptTemplate: Combine System + Human
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])
chat_prompt
# Out:
# ChatPromptTemplate(input_variables=['food_1', 'food_2', 'text'], messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['food_1', 'food_2'], template='Propose creative ways to incorporate {food_1} and {food_2} in the cuisine of the users choice.')), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['text'], template='{text}'))])

# %%
chat_prompt_with_values = chat_prompt.format_prompt(food_1="Bacon", \
                                                   food_2="Shrimp", \
                                                   text="I really like food from Germany.")

chat_prompt_with_values.to_messages()
# Out:
# [SystemMessage(content='Propose creative ways to incorporate Bacon and Shrimp in the cuisine of the users choice.'),
#  HumanMessage(content='I really like food from Germany.')]

# %%
response = chat(chat_prompt_with_values.to_messages()).content
print (response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 response = chat(chat_prompt_with_values.to_messages()).content
#       2 print (response)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:691, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     683 @deprecated("0.1.7", alternative="invoke", removal="0.2.0")
#     684 def __call__(
#     685     self,
#    (...)
#     689     **kwargs: Any,
#     690 ) -> BaseMessage:
# --> 691     generation = self.generate(
# ...

# %% [markdown]
# #### With Streaming

# %%
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
chat = ChatOpenAI(openai_api_key=openai_key, streaming=True, callback_manager=CallbackManager([StreamingStdOutCallbackHandler()]), verbose=True, temperature=0)

resp = chat(chat_prompt_with_values.to_messages())
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[21], line 5
#       2 from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
#       3 chat = ChatOpenAI(openai_api_key=openai_key, streaming=True, callback_manager=CallbackManager([StreamingStdOutCallbackHandler()]), verbose=True, temperature=0)
# ----> 5 resp = chat(chat_prompt_with_values.to_messages())
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~/Downloads/LangChain/lang/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:691, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
# ...
